# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaparvathi620/FMML/blob/main/Khub_Task(python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is a single line comments in python

# %%
"""This is a
multi
line
comment in python"""
# Out:
# 'This is a\nmulti\nline \ncomment in python'

# %%
'''this
is
 also multi
 line comment'''
# Out:
# 'this \nis\n also multi \n line comment'

# %%
#Python version
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
#Basic python code Syntax
print("Hello World!")
# Out:
# Hello World!

# %%
#Python Indentation
if 5>3:
  print("Five is a grater than 3")
# Out:
# Five is a grater than 3

# %%
#Python Indentation
if 5>3:
  print("Three less five")
# Out:
# Three less five

# %%
#Python Variables
X=5
Y=10
print(X,Y)
print(X)
print(Y)
# Out:
# 5 10
# 5
# 10

# %%
#get the variable type
X="Vijju"
Y=10
Z=3.5
print(type(Z))
print(type(X))
print(type(Y))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
#creating variables
A=str(3)
B=float(7)
C=int(10)
print(A)
print(B)
print(C)
# Out:
# 3
# 7.0
# 10

# %%
#Single or Double Quotes
A='SHIV'
print(A)
A="shiv"
print(A)
# Out:
# SHIV
# shiv

# %%
#Case senstive
Q="paruuu"
q="paruuu"
print(Q)
print(q)
# Out:
# paruuu
# paruuu

# %%
#variable name rules

'''Cannot starts with numbers
starts with alpha numeric and underscore'''

myvar="priyaa"
_myvar=10
MYVAR=2.0
_my_var=True
myvar5=100


print(myvar)
print(_myvar)
print(myvar5)
print(MYVAR)
print(_my_var)
# Out:
# priyaa
# 10
# 100
# 2.0
# True

# %%
#Multi Words Variable Names
#camel case
myVariableName = "John"

#Pascal Case
MyVariableName = "John"

#snake case
my_variable_name = "John"

# %%
#Assign multiple values
x,y,z=10,20,30
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# 10
# 20
# 30
# 10 20 30

# %%
#One Value to Multiple Variables
a=b=c="sanjuu"
print(a)
print(c)
# Out:
# sanjuu
# sanjuu

# %%
#Unpack a Collection
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
#output variables
a="python"
b="is very"
c="easy to read"
print(a,b,c)
print(a+b+c)
# Out:
# python is very easy to read
# pythonis veryeasy to read

# %%
#Mathematical operator variables

p=16
q=12
print(p+q)
print(p-q)
print(p/q)
print(p*q)
print(p//q)
print(p%q)
print(p**q)
print(p^q)
print(p&q)
print(p<<q)
print(p>>q)
# Out:
# 28
# 4
# 1.3333333333333333
# 192
# 1
# 4
# 281474976710656
# 28
# 0
# 65536
# 0

# %%
#global variables

x="super"

def myfunction():
  print("python is " +x)
myfunction()
# Out:
# python is super

# %%
x="super"
def myfunc():
  x="fantastic"
  print("python is " +x)
myfunc()
print("python is " +x)
# Out:
# python is fantastic
# python is super

# %%
#The Global Keyword

def func():
  global x
  x="super"
func()
print("python is "+x)
# Out:
# python is super
